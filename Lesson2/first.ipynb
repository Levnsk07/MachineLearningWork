# %% [markdown]
# > Error: don't work in pycharm and VS code

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('house_price_regression_dataset.csv')

from sklearn.linear_model import LinearRegression
model = LinearRegression()
